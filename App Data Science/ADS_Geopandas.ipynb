# %%
import geopandas as gpd

# %%
path = gpd.datasets.get_path('nybb')
df = gpd.read_file(path)
# Out:
# <ipython-input-2-4ddaa191f056>:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'nybb' data from the geodatasets package.
#
# from geodatasets import get_path
# path_to_file = get_path('nybb')
#
#   path = gpd.datasets.get_path('nybb')

# %%
df.head()
# Out:
#    BoroCode       BoroName     Shape_Leng    Shape_Area  \
# 0         5  Staten Island  330470.010332  1.623820e+09
# 1         4         Queens  896344.047763  3.045213e+09
# 2         3       Brooklyn  741080.523166  1.937479e+09
# 3         1      Manhattan  359299.096471  6.364715e+08
# 4         2          Bronx  464392.991824  1.186925e+09
#
#                                             geometry
# 0  MULTIPOLYGON (((970217.022 145643.332, 970227....
# 1  MULTIPOLYGON (((1029606.077 156073.814, 102957...
# 2  MULTIPOLYGON (((1021176.479 151374.797, 102100...
# 3  MULTIPOLYGON (((981219.056 188655.316, 980940....
# 4  MULTIPOLYGON (((1012821.806 229228.265, 101278...

# %%
type(df)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(column='BoroName',edgecolor='black',legend=True)
# Out:
# <Axes: >

# %%
df1=df[df['BoroName']=='Manhattan']

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df[df['BoroName']=='Queens'].plot()
# Out:
# <Axes: >

# %%
df.crs
# Out:
# <Projected CRS: EPSG:2263>
# Name: NAD83 / New York Long Island (ftUS)
# Axis Info [cartesian]:
# - X[east]: Easting (US survey foot)
# - Y[north]: Northing (US survey foot)
# Area of Use:
# - name: United States (USA) - New York - counties of Bronx; Kings; Nassau; New York; Queens; Richmond; Suffolk.
# - bounds: (-74.26, 40.47, -71.8, 41.3)
# Coordinate Operation:
# - name: SPCS83 New York Long Island zone (US Survey feet)
# - method: Lambert Conic Conformal (2SP)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
#kilometers
df.area/1000000
# Out:
# 0    1623.821997
# 1    3045.213694
# 2    1937.478349
# 3     636.471238
# 4    1186.926294
# dtype: float64

# %%
df['area'] = df.area

# %%
df.plot('area',legend = True)
# Out:
# <Axes: >

# %%
df['centroid'] = df.centroid

# %%
df.plot('centroid',legend = True)
# Out:
# <Axes: >

# %%
# !pip3 install geopandas folium matplotlib mapclassify

# %%
df.explore()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
